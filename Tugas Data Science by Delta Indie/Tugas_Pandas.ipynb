# %% [markdown]
# ANALISIS DATA PENJUALAN PRODUK CETAKAN MENGGUNAKAN PYTHON DENGAN LIBRARY PANDAS
#
# Nama   : Vina
#
# Produk : FoodpakMatte245
#
# Soal:
# 1. Hitung rata-rata penjualan dari produk FoodpakMatte245!
# 2. Di tanggal berapakah transaksi termahal terjadi?
# 3. Berapakah jumlah orderan terbanyak di produk FoodpakMatte245?
# 4. Berapa nilai terendah dari total pembelian yang terjadi di bulan 10 tahun 2023?
# 5. Di tanggal berapa nilai harga FoodpakMatte245 tertinggi?

# %%
# Import library pandas
import pandas as pd

# %%
# Import dataset
df=pd.read_csv("data_penjualan.csv",delimiter=";")
df
# Out:
#          Tanggal      Jenis Produk  Jumlah Order  Harga    Total
# 0     05/08/2022        Foodpak260          1000   1800  1800000
# 1     05/08/2022   FoodpakMatte245          1000   1900  1900000
# 2     05/08/2022  CraftLaminasi290          5000    750  3750000
# 3     05/08/2022  CraftLaminasi290          1000   1200  1200000
# 4     07/08/2022        Dupleks310          1000   1550  1550000
# ...          ...               ...           ...    ...      ...
# 1071  14/11/2023          Ivory230          1000    900   900000
# 1072  15/11/2023  CraftLaminasi290          2000    800  1600000
# 1073  15/11/2023  CraftLaminasi290          1500    875  1312500
# 1074  15/11/2023      FoodpakMatte          1000   2200  2200000
# 1075  15/11/2023       GreaseProof          1000    300   300000
#
# [1076 rows x 5 columns]

# %%
# Memfilter dataset untuk menampilkan produk 'FoodpakMatte245'
fm=df[df["Jenis Produk"]=="FoodpakMatte245"].copy()
fm
# Out:
#          Tanggal     Jenis Produk  Jumlah Order  Harga    Total
# 1     05/08/2022  FoodpakMatte245          1000   1900  1900000
# 37    18/08/2022  FoodpakMatte245          1000   1800  1800000
# 92    19/09/2022  FoodpakMatte245          2500    700  1750000
# 362   06/01/2023  FoodpakMatte245          1000   1500  1500000
# 371   06/01/2023  FoodpakMatte245          4000   1000  4000000
# 385   01/02/2023  FoodpakMatte245          1000    900   900000
# 388   01/02/2023  FoodpakMatte245          1000   1600  1600000
# 397   09/02/2023  FoodpakMatte245          1000   1200  1200000
# 430   19/02/2023  FoodpakMatte245          2000   1500  3000000
# 447   06/03/2023  FoodpakMatte245          2000   1500  3000000
# 482   23/03/2023  FoodpakMatte245          5000   1500  7500000
# 483   23/03/2023  FoodpakMatte245          4000   1050  4200000
# 493   28/03/2023  FoodpakMatte245          3000   1200  3600000
# 494   29/03/2023  FoodpakMatte245          3500   1200  4200000
# ...

# %%
# Mengetahui informasi umum untuk data jenis produk 'FoodpakMatte245'
fm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54 entries, 1 to 1049
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tanggal       54 non-null     object
#  1   Jenis Produk  54 non-null     object
#  2   Jumlah Order  54 non-null     int64
#  3   Harga         54 non-null     int64
#  4   Total         54 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.5+ KB

# %% [markdown]
# Terdapat 54 transaksi produk FoodpakMatte245.

# %% [markdown]
# 1. Hitung rata-rata penjualan dari produk FoodpakMatte245!

# %%
# Rata-rata penjualan produk FoodpakMatte245
round(fm["Total"].mean(),2)
# Out:
# 2861111.11

# %% [markdown]
# Rata-rata penjualan produk FoodpakMatte245 yaitu sebesar Rp 2.861.111,11.

# %% [markdown]
# 2. Di tanggal berapakah transaksi termahal terjadi?

# %%
# Menampilkan hanya satu tanggal pertama terjadinya transaksi termahal
fm.loc[fm["Total"].idxmax(),"Tanggal"]
# Out:
# '23/03/2023'

# %%
# Cara lain untuk menampilkan tanggal transaksi termahal

# Mendefinisikan nilai maksimum
maks_total=fm["Total"].max()
maks_total
# Out:
# 7500000

# %%
# Menampilkan seluruh tanggal dengan transaksi termahal
fm[fm["Total"]==maks_total]
# Out:
#         Tanggal     Jenis Produk  Jumlah Order  Harga    Total
# 482  23/03/2023  FoodpakMatte245          5000   1500  7500000
# 534  25/04/2023  FoodpakMatte245          5000   1500  7500000
# 576  06/05/2023  FoodpakMatte245          5000   1500  7500000

# %% [markdown]
# Terdapat tiga transaksi produk FoodpakMatte245 dengan total transaksi termahal sebesar Rp 7.500.000,00, yaitu pada tanggal 23 Maret 2023, 25 April 2023, dan 6 Juni 2023.

# %% [markdown]
# 3. Berapakah jumlah orderan terbanyak di produk FoodpakMatte245?

# %%
# Jumlah order terbanyak produk FoodpakMatte245
fm["Jumlah Order"].max()
# Out:
# 6000

# %% [markdown]
# Jumlah order terbanyak untuk produk FoodpakMatte245 yaitu sebanyak 6000 unit.

# %% [markdown]
# 4. Berapa nilai terendah dari total pembelian yang terjadi di bulan 10 tahun 2023?

# %%
# Mengubah kolom 'Tanggal' menjadi format datetime
fm["Tanggal"]=pd.to_datetime(fm["Tanggal"],format="%d/%m/%Y")
fm["Tanggal"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 54 entries, 1 to 1049
# Series name: Tanggal
# Non-Null Count  Dtype
# --------------  -----
# 54 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.9 KB

# %%
# Memfilter transaksi di bulan 10 tahun 2023
fm1023=fm[(fm["Tanggal"].dt.month==10) & (fm["Tanggal"].dt.year==2023)]
fm1023
# Out:
#         Tanggal     Jenis Produk  Jumlah Order  Harga    Total
# 977  2023-10-12  FoodpakMatte245          1000   1500  1500000
# 978  2023-10-12  FoodpakMatte245          4000   1500  6000000
# 985  2023-10-14  FoodpakMatte245           500   1500   750000
# 986  2023-10-14  FoodpakMatte245           500   1300   650000
# 994  2023-10-18  FoodpakMatte245          2000   1000  2000000
# 1002 2023-10-20  FoodpakMatte245          1000   2400  2400000
# 1010 2023-10-24  FoodpakMatte245          1000   1700  1700000
# 1029 2023-10-30  FoodpakMatte245          4000   1500  6000000
# 1031 2023-10-31  FoodpakMatte245          2000   1000  2000000

# %%
# Menampilkan transaksi terendah di bulan 10 tahun 2023
fm1023["Total"].min()
# Out:
# 650000

# %% [markdown]
# Nilai terendah dari total pembelian yang terjadi di bulan 10 tahun 2023 yaitu sebesar Rp 650.000,00.

# %% [markdown]
# 5. Di tanggal berapa nilai harga FoodpakMatte245 tertinggi?

# %%
# Menampilkan hanya satu tanggal pertama terjadinya harga tertinggi
fm.loc[fm["Harga"].idxmax(),"Tanggal"]
# Out:
# Timestamp('2023-10-20 00:00:00')

# %%
# Cara lain untuk menampilkan tanggal dengan harga tertinggi

# Mendefinisikan nilai maksimum harga
maks_harga=fm["Harga"].max()
maks_harga
# Out:
# 2400

# %%
# Menampilkan tanggal dengan harga tertinggi
fm[fm["Harga"]==maks_harga]
# Out:
#         Tanggal     Jenis Produk  Jumlah Order  Harga    Total
# 1002 2023-10-20  FoodpakMatte245          1000   2400  2400000

# %% [markdown]
# Transaksi FoodpakMatte245 dengan harga tertinggi sebesar Rp 2.400,00 terjadi pada tanggal 20 Oktober 2023.
